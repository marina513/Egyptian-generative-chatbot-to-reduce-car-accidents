# %%
from cam_text_open import camera_pred
camera_pred(False) # run sleep or no
# Out:
#  iter num :  0
# C:\Users\AnyOneElse\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:3891: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# C:\Users\AnyOneElse\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:3829: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
#  iter num :  1
#  iter num :  2
#  iter num :  3
# ***********************  8 emotions ***************
# @************************************************@
# most frequent prediction:  sad
# ...
